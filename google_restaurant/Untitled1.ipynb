# %%
import pandas as pd

# %%
df = pd.read_csv('data7.csv')
df
# Out:
#                                        name               street zipcode  \
# 0             Sushi Für Hamburg Norderstedt     Elbgaustraße 126   22547
# 1     China Restaurant Mongolei Norderstedt         Marktpl. 3-5   22844
# 2                  Restaurant "Haus am See"      im Stadtpark 55   22844
# 3                    Steakhouse Meeschensee        Elfenhagen 51   22844
# 4                Restaurant Binnen un Buten  Ulzburger Str. 476A   22844
# ...                                     ...                  ...     ...
# 1097                                  Shell  Freiheitsstraße 234   41747
# 1098      Ulla Popken - Large Sizes Viersen     Petersstraße 2-4   41747
# 1099        Ristorante Mala - Lavdim Ferati     Kärntner Str. 42   41063
# 1100             Hotel Restaurant Heidehaus   Viersener Str. 285   41063
# 1101                     Restaurant Neuzeit         Gathersweg 1   41066
#
#                  town  rating  total_reviews
# 0             Hamburg     4.3    213 reviews
# ...

# %%
df['total_reviews'] = df['total_reviews'].str.replace(',','').str.replace(' reviews','').str.replace(' review','')
df = df[df['total_reviews'].notna()]
df['total_reviews'] = df['total_reviews'].astype(int)
df[df['total_reviews'] < 30]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-2958224c895b> in <module>
# ----> 1 df['total_reviews'] = df['total_reviews'].str.replace(',','').str.replace(' reviews','').str.replace(' review','')
#       2 df = df[df['total_reviews'].notna()]
#       3 df['total_reviews'] = df['total_reviews'].astype(int)
#       4 df[df['total_reviews'] < 30]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
# ...

# %%
df = pd.read_csv('final.csv')
df
# Out:
#                                             name                      street  \
# 0     Restaurant CHOI - Korean dining experience         Fehrbelliner Str. 4
# 1            Precise Tale Berlin Potsdamer Platz         Stresemannstraße 95
# 2                                        Bonfini           Chausseestraße 15
# 3                                         Cô Chu          Invalidenstraße 29
# 4                                    Golden Rice           Chausseestraße 29
# ...                                          ...                         ...
# 5995                                         EAT   An d. Germania Brauerei 5
# 5996                                   Zevbbbbna           Grevener Str. 222
# 5997                       Döner & Pizza Company                Am Burloh 97
# 5998               Papa George Nienberge Münster         Haus Uhlenkotten 6e
# 5999     Mensa BWZ Münster, Generalzolldirektion               Gescherweg 96
#
# ...

# %%
import numpy as np
df['total_reviews'] = df['total_reviews'].fillna(value=np.random.randn())

# %%
df['total_reviews'] = df['total_reviews'].str.replace(' reviews','')
df['total_reviews'] = df['total_reviews'].str.replace(' review','')

# %%
df['rating'] = df['rating'].astype(float)
df
# Out:
#                                             name                      street  \
# 0     Restaurant CHOI - Korean dining experience         Fehrbelliner Str. 4
# 1            Precise Tale Berlin Potsdamer Platz         Stresemannstraße 95
# 2                                        Bonfini           Chausseestraße 15
# 3                                         Cô Chu          Invalidenstraße 29
# 4                                    Golden Rice           Chausseestraße 29
# ...                                          ...                         ...
# 5995                                         EAT   An d. Germania Brauerei 5
# 5996                                   Zevbbbbna           Grevener Str. 222
# 5997                       Döner & Pizza Company                Am Burloh 97
# 5998               Papa George Nienberge Münster         Haus Uhlenkotten 6e
# 5999     Mensa BWZ Münster, Generalzolldirektion               Gescherweg 96
#
#       zipcode     town  rating total_reviews
# ...

# %%
df.to_csv('final_v1.csv',index=False)

# %%
df1 = pd.read_csv('final_v1.csv',encoding='utf-8')
df1
# Out:
#                                             name                     street  \
# 0     Restaurant CHOI - Korean dining experience        Fehrbelliner Str. 4
# 1            Precise Tale Berlin Potsdamer Platz        Stresemannstraße 95
# 2                                        Bonfini          Chausseestraße 15
# 3                                         Cô Chu         Invalidenstraße 29
# 4                                    Golden Rice          Chausseestraße 29
# ...                                          ...                        ...
# 5995                                         EAT  An d. Germania Brauerei 5
# 5996                                   Zevbbbbna          Grevener Str. 222
# 5997                       Döner & Pizza Company               Am Burloh 97
# 5998               Papa George Nienberge Münster        Haus Uhlenkotten 6e
# 5999     Mensa BWZ Münster, Generalzolldirektion              Gescherweg 96
#
#       zipcode     town  rating total_reviews
# ...

# %%
df1['rating'] = df1['rating'].astype(str)
df1['rating'] = df1['rating'].str.replace('4','4.0')
df1['rating'].unique()
# Out:
# array(['4.0.7', '4.0.3', '4.0.2', '4.0.5', '4.0.4.0', '4.0.1', '4.0.6',
#        '4.0.0', '4.0.8', '5.0', '4.0.9'], dtype=object)

# %%
import pandas as pd
testing = pd.read_csv('testing.csv',encoding='ISO-8859-1')
testing
# Out:
#                                             name                     street  \
# 0     Restaurant CHOI - Korean dining experience        Fehrbelliner Str. 4
# 1            Precise Tale Berlin Potsdamer Platz        Stresemannstraße 95
# 2                                        Bonfini          Chausseestraße 15
# 3                                         Cô Chu         Invalidenstraße 29
# 4                                    Golden Rice          Chausseestraße 29
# ...                                          ...                        ...
# 5995                                         EAT  An d. Germania Brauerei 5
# 5996                                   Zevbbbbna          Grevener Str. 222
# 5997                       Döner & Pizza Company               Am Burloh 97
# 5998               Papa George Nienberge Münster        Haus Uhlenkotten 6e
# 5999     Mensa BWZ Münster, Generalzolldirektion              Gescherweg 96
#
#       zipcode     town  rating total_reviews  new_rating
# ...

# %%
testing['zipcode'] = testing['zipcode'].astype(str)
testing['zipcode'] = testing['zipcode'].str.zfill(5)
testing['name'] = testing['name'].str.replace('"','')

# %%
testing['zipcode'].dtype
# Out:
# dtype('O')

# %%
testing[testing['name'] == 'Grill Pizzeria OLYMP']
# testing
# Out:
#                       name             street zipcode   town  rating  \
# 2783  Grill Pizzeria OLYMP  Frankenstraße 374   45133  Essen     4.2
#
#      total_reviews  new_rating
# 2783           420         4.2

# %%
testing.to_csv('testing1.csv',index=False)

# %%
testing['town'].unique()
# Out:
# array(['Berlin', 'Hamburg', 'München', 'Köln', 'Frankfurt am Main',
#        'Stuttgart', 'Düsseldorf', 'Leipzig', 'Dortmund', 'Essen',
#        'Bremen', 'Dresden', 'Hannover', 'Nürnberg', 'Duisburg', 'Bochum',
#        'Wuppertal', 'Bielefeld', 'Bonn', 'Münster'], dtype=object)

# %%
testing.dtypes
# Out:
# name              object
# street            object
# zipcode           object
# town              object
# rating           float64
# total_reviews     object
# new_rating       float64
# dtype: object

# %%
test = pd.read_excel('full_final.xlsx')
test
# Out:
#                                             name                     street  \
# 0     Restaurant CHOI - Korean dining experience        Fehrbelliner Str. 4
# 1            Precise Tale Berlin Potsdamer Platz        Stresemannstraße 95
# 2                                        Bonfini          Chausseestraße 15
# 3                                         Cô Chu         Invalidenstraße 29
# 4                                    Golden Rice          Chausseestraße 29
# ...                                          ...                        ...
# 5995                                         EAT  An d. Germania Brauerei 5
# 5996                                   Zevbbbbna          Grevener Str. 222
# 5997                       Döner & Pizza Company               Am Burloh 97
# 5998               Papa George Nienberge Münster        Haus Uhlenkotten 6e
# 5999     Mensa BWZ Münster, Generalzolldirektion              Gescherweg 96
#
# ...

# %%
test1 = test[test['total_reviews'] < 30]
test1
# Out:
#                                          name                    street  \
# 14                 CRAFTERIE Restaurant & Bar         Chausseestraße 33
# 68                          HALLO! Milk & Tea             Torstraße 210
# 119                                   Dehlers        Reinhardtstraße 14
# 125                   TASTE! Bar & Restaurant        Friedrichstraße 96
# 142                Kitchen & Bar at Courtyard   Axel-Springer-Straße 55
# ...                                       ...                       ...
# 5945             GOLFCLUB RESTAURANT HESSFELD  Steinfurter Str. 448/450
# 5952                               DARI GRILL        Sprickmannstraße 8
# 5983            Penthouse 13 Privatrestaurant        Dieckmannstraße 62
# 5989                        Pan Pizza Münster      Scharnhorststraße 61
# 5999  Mensa BWZ Münster, Generalzolldirektion             Gescherweg 96
#
#       zipcode     town  rating  total_reviews  new_rating
# ...

# %%
test1['name'] = test1['name'].str.replace('?','').str.replace('¶','')
test1['street'] = test1['street'].str.replace('¶','')
# Out:
# <ipython-input-20-1128b86b8b24>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test1['name'] = test1['name'].str.replace('?','').str.replace('¶','')
# <ipython-input-20-1128b86b8b24>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test1['street'] = test1['street'].str.replace('¶','')

# %%
test1
# Out:
#                                                    name  \
# 0            Restaurant CHOI - Korean dining experience
# 1                   Precise Tale Berlin Potsdamer Platz
# 2                                               Bonfini
# 3                                                Cô Chu
# 4                                           Golden Rice
# ...                                                 ...
# 5994  Restaurant Jü Xin Mongolischer Grill und China...
# 5995                                                EAT
# 5996                                          Zevbbbbna
# 5997                              Döner & Pizza Company
# 5998                      Papa George Nienberge Münster
#
#                          street  zipcode     town  rating  total_reviews  \
# 0           Fehrbelliner Str. 4    10119   Berlin     4.7            205
# 1           Stresemannstraße 95    10963   Berlin     4.3             56
# ...

# %%
test1 = test1[~test1['name'].str.contains('Tankstelle')]
test1
# Out:
#                                                    name  \
# 0            Restaurant CHOI - Korean dining experience
# 1                   Precise Tale Berlin Potsdamer Platz
# 2                                               Bonfini
# 3                                                Cô Chu
# 4                                           Golden Rice
# ...                                                 ...
# 5994  Restaurant Jü Xin Mongolischer Grill und China...
# 5995                                                EAT
# 5996                                          Zevbbbbna
# 5997                              Döner & Pizza Company
# 5998                      Papa George Nienberge Münster
#
#                          street  zipcode     town  rating  total_reviews  \
# 0           Fehrbelliner Str. 4    10119   Berlin     4.7            205
# 1           Stresemannstraße 95    10963   Berlin     4.3             56
# ...

# %%
test1.to_excel('again_testing.xlsx',index=False)

# %%
data = pd.read_excel('data.xlsx')
data
# Out:
#                                   name                          street  \
# 0                 "goodfood" offenbach          Strahlenbergerstraße 9
# 1                 "goodfood" offenbach          Strahlenbergerstraße 9
# 2     ...angekommen die Frittenstation  Hans-Dietrich-Genscher-Platz 4
# 3              .masa japanese soulfood                   Luegallee 130
# 4           „Il Campione“ Sport Bistro               Prämienstraße 146
# ...                                ...                             ...
# 1495                         Zur Taste                 Schloßstraße 27
# 1496                         Zur Taste                 Schloßstraße 27
# 1497                    Zur Wickenburg              Mülheimer Str. 130
# 1498             Zurbrüggen Restaurant              Herforder Str. 306
# 1499   حلويات البيك Süßigkeiten ALBAIK            Frankfurter Str. 11،
#
#      zipcode               town rating  total_reviews
# 0      63067  Offenbach am Main    4.7              7
# ...

# %%
data1 = data.drop_duplicates(subset=['name','street'],keep='first')
data1.to_excel('data.xlsx',index=False)

# %%
test2 = test1.append(data1)

# %%
test2
# Out:
#                                      name                   street zipcode  \
# 14             CRAFTERIE Restaurant & Bar        Chausseestraße 33   10115
# 68                      HALLO! Milk & Tea            Torstraße 210   10115
# 119                               Dehlers       Reinhardtstraße 14   10117
# 125               TASTE! Bar & Restaurant       Friedrichstraße 96   10117
# 142            Kitchen & Bar at Courtyard  Axel-Springer-Straße 55   10117
# ...                                   ...                      ...     ...
# 1493  Zur Talquelle Inh. Rosemarie Nöllen              Schirick 34   41751
# 1495                            Zur Taste          Schloßstraße 27   42551
# 1497                       Zur Wickenburg       Mülheimer Str. 130   45145
# 1498                Zurbrüggen Restaurant       Herforder Str. 306   33609
# 1499      حلويات البيك Süßigkeiten ALBAIK     Frankfurter Str. 11،   63065
#
#                    town rating  total_reviews  new_rating
# ...

# %%
test2 = test2.drop_duplicates(subset=['name','street'],keep='first')
test2.total_reviews.unique()
# Out:
# array([ 7,  9, 22,  2, 19,  3, 15, 14,  1, 11,  5, 28, 10, 23,  4, 16, 25,
#        20, 27, 21, 17,  8,  6, 12, 18, 13, 26, 24, 29], dtype=int64)

# %%
csv_data = pd.read_csv('final_v1.csv')
csv_data
# Out:
#                                             name                     street  \
# 0     Restaurant CHOI - Korean dining experience        Fehrbelliner Str. 4
# 1            Precise Tale Berlin Potsdamer Platz        Stresemannstraße 95
# 2                                        Bonfini          Chausseestraße 15
# 3                                         Cô Chu         Invalidenstraße 29
# 4                                    Golden Rice          Chausseestraße 29
# ...                                          ...                        ...
# 5995                                         EAT  An d. Germania Brauerei 5
# 5996                                   Zevbbbbna          Grevener Str. 222
# 5997                       Döner & Pizza Company               Am Burloh 97
# 5998               Papa George Nienberge Münster        Haus Uhlenkotten 6e
# 5999     Mensa BWZ Münster, Generalzolldirektion              Gescherweg 96
#
#       zipcode     town  rating total_reviews
# ...

# %%
test3 = test2.append(csv_data)
test3
# Out:
#                                          name                     street  \
# 14                 CRAFTERIE Restaurant & Bar          Chausseestraße 33
# 68                          HALLO! Milk & Tea              Torstraße 210
# 119                                   Dehlers         Reinhardtstraße 14
# 125                   TASTE! Bar & Restaurant         Friedrichstraße 96
# 142                Kitchen & Bar at Courtyard    Axel-Springer-Straße 55
# ...                                       ...                        ...
# 5995                                      EAT  An d. Germania Brauerei 5
# 5996                                Zevbbbbna          Grevener Str. 222
# 5997                    Döner & Pizza Company               Am Burloh 97
# 5998            Papa George Nienberge Münster        Haus Uhlenkotten 6e
# 5999  Mensa BWZ Münster, Generalzolldirektion              Gescherweg 96
#
#      zipcode     town rating total_reviews  new_rating
# ...

# %%
test3 = test3.drop_duplicates(subset=['name','street'],keep='first')
test3
# Out:
#                                                    name  \
# 14                           CRAFTERIE Restaurant & Bar
# 68                                    HALLO! Milk & Tea
# 119                                             Dehlers
# 125                             TASTE! Bar & Restaurant
# 142                          Kitchen & Bar at Courtyard
# ...                                                 ...
# 5994  Restaurant Jü Xin Mongolischer Grill und China...
# 5995                                                EAT
# 5996                                          Zevbbbbna
# 5997                              Döner & Pizza Company
# 5998                      Papa George Nienberge Münster
#
#                          street zipcode     town rating total_reviews  \
# 14            Chausseestraße 33   10115   Berlin    4.4             7
# 68                Torstraße 210   10115   Berlin    4.1             9
# 119          Reinhardtstraße 14   10117   Berlin    4.1            22
# ...

# %%
# test3[test3['total_reviews'] < 30]
test3['total_reviews'] = test3['total_reviews'].str.replace(',','')
test3 = test3[test3['total_reviews'].notna()]
test3['total_reviews'] = test3['total_reviews'].astype(int)
test3[test3['total_reviews'] < 30]
# test3['total_reviews'].unique()
# Out:
# <ipython-input-44-fec2eb6a78aa>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test3['total_reviews'] = test3['total_reviews'].str.replace(',','')
# <ipython-input-44-fec2eb6a78aa>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test3['total_reviews'] = test3['total_reviews'].astype(int)
#                                                    name            street  \
# 458   Lunch-Karawane "City Süd" (Food Truck-Halteste...      Nagelsweg 37
# ...
